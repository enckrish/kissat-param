# %%
# Out:
# nb_01.ipynb  representation-learning.ipynb

# %%
# !pip show jedi
# Out:
# Name: jedi
# Version: 0.19.2
# Summary: An autocompletion tool for Python that can be used for text editors.
# Home-page: https://github.com/davidhalter/jedi
# Author: David Halter
# Author-email: davidhalter88@gmail.com
# License: MIT
# Location: /home/krishnendu/Research/fv-invariant-mining/.venv/lib64/python3.14/site-packages
# Requires: parso
# Required-by: ipython
